# %% [markdown]
# # Getting the Data and Environment

# %%
# Download gutenberg dataset
# This is the dataset on which all your models will be trained
# https://drive.google.com/file/d/0B2Mzhc7popBga2RkcWZNcjlRTGM/edit

# Step 1: Get the corpus and load it in

import os
def get_corpus (n):
    files = [f for f in os.listdir("./Gutenberg") if os.path.isfile(os.path.join("./Gutenberg", f))]
    count = 0
    for f in files:
        count += 1
    # print ("There are " + str(count) + " files in this corpus.")
    if n > count:
        return 0
    else:
        return files [n-1]

# %% [markdown]
# # Part 1a: Split into Sentences and Tokenization

# %%
import sys, re

def clean(text):
    # text is stripped of all extra white spaces here
    cleaned_text = re.sub(r'[\s]+', ' ',text)
    return cleaned_text


caps = "([A-Z])"
prefixes = "(Mr|St|Mrs|Ms|Dr)[.]"
suffixes = "(Inc|Ltd|Jr|Sr|Co)"
starters = "(Mr|Mrs|Ms|Dr|He\s|She\s|It\s|They\s|Their\s|Our\s|We\s|But\s|However\s|That\s|This\s|Wherever)"
acronyms = "([A-Z][.][A-Z][.](?:[A-Z][.])?)"

def replace (text):
    text = re.sub(prefixes,"\\1<prd>",text)
    if "Ph.D" in text: 
        text = text.replace("Ph.D.","Ph<prd>D<prd>")
        
    text = re.sub("\s" + caps + "[.] "," \\1<prd> ",text)
    text = re.sub(acronyms+" "+starters,"\\1<stop> \\2",text)
    text = re.sub(caps + "[.]" + caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>\\3<prd>",text)
    text = re.sub(caps + "[.]" + caps + "[.]","\\1<prd>\\2<prd>",text)
    text = re.sub(" "+suffixes+"[.] "+starters," \\1<stop> \\2",text)
    text = re.sub(" "+suffixes+"[.]"," \\1<prd>",text)
    text = re.sub(" " + caps + "[.]"," \\1<prd>",text)
    
    if "”" in text: 
        text = text.replace(".”","”.")
    if "\"" in text: 
        text = text.replace(".\"","\".")
    if "!" in text: 
        text = text.replace("!\"","\"!")
    if "?" in text: 
        text = text.replace("?\"","\"?")
        
    text = text.replace(".",".<stop>")
    text = text.replace("?","?<stop>")
    text = text.replace("!","!<stop>")
    text = text.replace("<prd>",".")
    return text

def sentencizer(text):   
    text = " " + text + "  "
    text = text.replace("\n"," ")
    
    text = replace(text)
    sentences = text.split("<stop>")
    sentences = sentences[:-1]
    sentences = [s.strip() for s in sentences]
    return sentences

def tokenize(sentences):
    # sentences is a list of sentences, which is a list of words
    tokenized_sentences = []
    for line in sentences:
        for tokens in line:
            tokenized_sentences.append(re.findall("[A-Z]{2,}(?![a-z])|[A-Z][a-z]+(?=[A-Z])|[\w]+",tokens))
    return tokenized_sentences
    
def characterizer(word):
    characterized_words = []
    for ch in word:
        characterized_words.append(str(ch))
    return characterized_words

# %% [markdown]
# # Part 1b: Initial Language Model

# %%
def get_and_sort(n, size, corpus, loc):
    tokens = get_ngrams(n, corpus)
    sorted_tokens = sorted(tokens.items(), key = lambda x: x[1], reverse=True)
    if (loc == 't'):
        sorted_tokens = sorted_tokens[:size]
    if (loc == 'b'):
        sorted_tokens = sorted_tokens[-size:]
    return (sorted_tokens)

def get_unigrams(corpus):
    tokens = {}
    for sentence in corpus:
        for word in sentence:
            if word not in tokens: 
                tokens[word] = 0
            tokens[word] += 1
    return tokens

def get_bigrams(corpus):
    bigrams = {}
    for sentence in corpus:
        for index, word in enumerate(sentence):
            if index > 0:
                pair  = (sentence[index - 1], word)
                if pair not in bigrams:
                    bigrams[pair] = 0
                bigrams[pair] += 1
    return bigrams

def get_trigrams(corpus):
    trigrams = {}
    for sentence in corpus:
        for index, word in enumerate(sentence):
            if index > 1:
                three = (sentence[index - 2], sentence[index - 1], word)
                if three not in trigrams:
                    trigrams[three] = 0
                trigrams[three] += 1
    return trigrams

def get_fourgrams(corpus):
    fourgrams = {}
    for sentence in corpus:
        for index, word in enumerate(sentence):
            if index > 2:
                four = (sentence[index - 3], sentence[index - 2], sentence[index - 1], word)
                if four not in fourgrams:
                    fourgrams[four] = 0
                fourgrams[four] += 1
    return fourgrams

def get_ngrams(n, corpus):
    ngrams = {}
    if n == 1:
        ngrams = get_unigrams(corpus)
    elif n == 2:
        ngrams = get_bigrams(corpus)
    elif n == 3:
        ngrams = get_trigrams(corpus)
    elif n == 4:
        ngrams = get_fourgrams(corpus)
    return ngrams

def get_frequencies(count_ngrams):
    total = sum([count for (_, count) in count_ngrams])
    return [(gram, count / total) for (gram, count) in count_ngrams]

# %% [markdown]
# # Part 1c: Zipf's Law Implementation

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
init_notebook_mode(connected=True)

def get_curves(m, tab_size, corpus):
    graphable_ngrams = get_and_sort(m, tab_size*100, corpus, 't')
    if m == 1:
        iplot([{"x" : list(zip(*graphable_ngrams))[0], "y": list(zip(*graphable_ngrams))[1]}])
    else:
        iplot([{"x" : ['_'.join(x) for x in list(zip(*graphable_ngrams))[0]], "y": list(zip(*graphable_ngrams))[1]}])
        
def get_tables(n, tab_size, corpus):
    top_sorted_nchars = get_and_sort(n, tab_size, corpus, 't')
    bottom_sorted_nchars = get_and_sort(n, tab_size, corpus, 'b')
    top_frequency_nchars = get_frequencies(top_sorted_nchars)
    bottom_frequency_nchars = get_frequencies(bottom_sorted_nchars)
    print(top_sorted_nchars)
    print(bottom_sorted_nchars)
    
from ipy_table import *
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Part 1 Executable

# %%
file = get_corpus(1061)
f = open("./Gutenberg/" + file, "+r")
    
text = f.read()
    
# Step one, clean the corpus. 
cleaned_text = clean(text)

# Step two, split into sentences.
split_text = sentencizer(cleaned_text)
    
# Step three, tokenize
untokenized_text = []
for sentence in split_text:
    untokenized_text.append([sentence])
    
corpus = tokenize (untokenized_text)

characterized_corpus = []
for sentence in corpus:
    for word in sentence:
        characterized_corpus.append(characterizer(word))

# Step four, get ngrams, frequencies and the Zipf's curves
unigrams_sorted = get_and_sort(1, 1000, corpus, 't')
bigrams_sorted = get_and_sort(2, 1000, corpus, 't')
trigrams_sorted = get_and_sort(3, 1000, corpus, 't')
fourgrams_sorted = get_and_sort(4, 1000, corpus, 't')

m = 1
n = 3
tab = 5
get_tables(m, tab, corpus)
get_curves(m, tab, corpus)
get_tables(n, tab, characterized_corpus)
get_curves(n, tab, characterized_corpus)
# Out:
# [('the', 5143), ('to', 2603), ('of', 2577), ('and', 2494), ('a', 1935)]
# [('perennial', 1), ('obliterate', 1), ('legend', 1), ('Romance', 1), ('END', 1)]
# <div id="c256023c-b5e4-4b13-a8a6-99d4dc1a1194" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c256023c-b5e4-4b13-a8a6-99d4dc1a1194", [{"x": ["the", "to", "of", "and", "a", "that", "in", "I", "was", "his", "he", "you", "with", "it", "for", "not", "as", "is", "had", "at", "on", "be", "have", "her", "but", "him", "which", "so", "me", "my", "Bladud", "by", "they", "she", "were", "will", "this", "from", "said", "s", "The", "been", "one", "your", "or", "if", "all", "we", "man", "an", "when", "up", "there", "no", "who", "them", "would", "are", "their", "time", "prince", "what", "men", "It", "well", "out", "into", "old", "He", "do", "But", "may", "some", "more", "about", "Branwen", "little", "returned", "know", "did", "could", "has", "now", "like", "chief", "captain", "other", "much", "than", "see", "can", "am", "head", "our", "down", "very", "Maikar", "being", "only", "way", "over", "Hebrew", "good", "before", "long", "come", "say", "must", "You", "woman", "though", "king", "such", "father", "t", "Beniah", "Gunrig", "go", "day", "too", "Gadarn", "few", "eyes", "made", "then", "off", "us", "found", "himself", "its", "look", "think", "where", "two", "should", "far", "after", "Cormac", "while", "course", "just", "shall", "here", "tell", "asked", "hand", "great", "first", "friend", "any", "face", "That", "find", "away", "however", "Then", "might", "girl", "A", "even", "moment", "left", "never", "let", "home", "those", "At", "Arkal", "hut", "yet", "went", "came", "same", "back", "boy", "seen", "many", "And", "round", "young", "replied", "these", "make", "almost", "sure", "There", "mind", "through", "Swamp", "without", "life", "What", "quite", "mother", "As", "land", "right", "also", "take", "We", "Dromas", "last", "exclaimed", "Hafrydda", "once", "voice", "how", "side", "turned", "princess", "another", "looked", "poor", "still", "search", "She", "water", "place", "lad", "stood", "If", "Hudibras", "something", "No", "seemed", "thought", "heard", "end", "days", "They", "In", "youth", "both", "don", "tone", "own", "took", "point", "night", "nothing", "continued", "became", "Well", "wild", "people", "upon", "bow", "This", "part", "hope", "again", "laugh", "sword", "enough", "woods", "hunter", "set", "strong", "sea", "fair", "surprise", "began", "son", "daughter", "put", "m", "give", "till", "gave", "knew", "King", "fire", "keep", "things", "cried", "Hot", "soon", "fear", "Yes", "lost", "Ay", "indeed", "Now", "most", "full", "told", "ready", "large", "short", "want", "lay", "done", "each", "disease", "least", "town", "answered", "suddenly", "nature", "minutes", "seems", "CHAPTER", "remarked", "friends", "having", "thus", "light", "doubt", "under", "need", "love", "sent", "better", "work", "looking", "felt", "news", "hands", "spoke", "leave", "rather", "ever", "smile", "run", "cannot", "near", "gone", "going", "among", "arrow", "known", "myself", "fell", "To", "until", "spot", "three", "queen", "help", "Come", "truth", "small", "mean", "heart", "together", "All", "entered", "door", "whom", "true", "Captain", "during", "get", "return", "feel", "dear", "got", "close", "care", "robbers", "hot", "thing", "Brownie", "whether", "whose", "Indeed", "does", "somewhat", "visit", "brother", "Not", "saw", "camp", "against", "ground", "behind", "tree", "One", "pretty", "Of", "speak", "air", "caused", "strange", "food", "ll", "given", "use", "My", "fight", "silence", "cut", "state", "Oh", "observed", "seem", "reached", "When", "understand", "pigs", "Albion", "rest", "towards", "dark", "turning", "times", "manner", "followed", "whole", "room", "kind", "taken", "direction", "passed", "held", "women", "warriors", "herself", "beyond", "morning", "games", "strength", "hair", "arm", "led", "between", "For", "always", "matter", "caught", "every", "although", "child", "within", " ...
# [(('t', 'h', 'e'), 7126), (('a', 'n', 'd'), 2953), (('i', 'n', 'g'), 2635), (('h', 'e', 'r'), 1810), (('h', 'a', 't'), 1774)]
# [(('M', 'e', 'n'), 1), (('T', 'i', 'm'), 1), (('S', 'a', 'x'), 1), (('a', 'x', 'o'), 1), (('x', 'o', 'n'), 1)]
# <div id="c192a4cf-7d72-4e17-b9a1-9a08164c50a2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c192a4cf-7d72-4e17-b9a1-9a08164c50a2", [{"x": ["t_h_e", "a_n_d", "i_n_g", "h_e_r", "h_a_t", "t_h_a", "h_i_s", "y_o_u", "f_o_r", "e_r_e", "i_t_h", "w_a_s", "w_i_t", "n_o_t", "e_n_t", "t_e_r", "v_e_r", "n_c_e", "a_v_e", "i_o_n", "o_u_r", "o_m_e", "a_l_l", "t_h_i", "g_h_t", "e_a_r", "o_u_t", "m_a_n", "h_a_d", "i_l_l", "u_g_h", "w_h_i", "r_i_n", "t_e_d", "e_v_e", "h_a_v", "h_i_m", "o_n_e", "t_i_o", "e_l_l", "m_e_n", "i_g_h", "e_s_s", "a_i_n", "h_o_u", "r_e_a", "o_u_n", "o_u_l", "a_t_e", "i_n_t", "t_u_r", "T_h_e", "u_l_d", "o_t_h", "r_e_d", "h_i_n", "b_u_t", "n_e_d", "u_n_d", "r_e_s", "w_e_r", "h_i_c", "s_h_e", "h_e_n", "l_a_d", "a_r_e", "e_e_n", "i_c_h", "c_o_n", "o_r_e", "c_o_u", "e_r_s", "r_a_n", "n_t_e", "c_o_m", "i_d_e", "i_v_e", "n_d_e", "o_u_g", "r_o_m", "t_h_o", "p_r_i", "d_e_r", "i_n_d", "w_i_l", "o_v_e", "e_s_t", "h_e_y", "w_h_e", "n_o_w", "i_n_c", "a_i_d", "e_n_d", "a_d_u", "B_l_a", "h_a_n", "d_u_d", "a_s_t", "t_i_n", "u_r_n", "s_e_e", "o_w_n", "o_o_d", "k_i_n", "e_a_d", "i_m_e", "s_a_i", "h_e_a", "f_r_o", "e_a_t", "b_l_e", "u_r_e", "e_c_t", "r_o_u", "a_t_i", "w_h_o", "a_m_e", "s_o_m", "s_h_o", "r_e_t", "s_t_r", "o_s_e", "p_r_o", "s_t_e", "s_t_a", "s_e_l", "l_e_d", "o_r_t", "r_i_e", "o_l_d", "o_n_g", "r_n_e", "s_e_d", "b_e_e", "t_i_m", "u_s_t", "a_r_t", "a_r_d", "u_c_h", "t_e_n", "o_o_k", "o_u_s", "a_n_c", "a_t_h", "o_n_s", "v_e_n", "p_e_r", "t_a_i", "p_r_e", "a_c_e", "e_a_s", "k_n_o", "i_n_e", "l_i_n", "a_n_t", "k_e_d", "i_l_e", "t_r_a", "h_e_m", "t_t_e", "b_o_u", "i_s_e", "m_e_d", "l_e_a", "w_h_a", "u_n_t", "r_o_w", "c_h_i", "w_o_u", "w_e_n", "l_o_o", "s_t_i", "i_t_t", "m_i_n", "o_w_e", "t_l_e", "d_i_s", "a_k_e", "u_s_e", "i_e_d", "f_u_l", "m_o_r", "t_o_o", "w_a_y", "w_e_l", "a_r_r", "w_a_r", "l_o_w", "l_i_t", "n_i_n", "n_t_i", "h_e_i", "w_o_r", "p_a_r", "d_e_d", "e_l_y", "e_i_r", "e_l_f", "e_t_u", "t_l_y", "i_e_n", "r_s_e", "e_n_c", "s_p_e", "r_a_t", "s_i_d", "p_l_a", "u_r_s", "o_s_t", "n_l_y", "o_m_a", "s_t_o", "h_o_w", "d_e_s", "d_e_n", "d_i_n", "a_b_o", "a_g_e", "e_e_d", "r_i_g", "c_a_p", "s_h_a", "l_o_n", "o_i_n", "a_b_l", "e_n_i", "t_t_l", "p_o_s", "i_k_e", "r_e_c", "l_e_s", "a_n_g", "a_n_y", "s_e_a", "n_g_e", "i_s_t", "t_h_r", "h_a_s", "t_a_n", "r_e_m", "s_u_r", "a_c_t", "h_e_d", "a_p_t", "s_s_i", "n_t_o", "e_r_y", "c_t_i", "b_r_e", "i_t_e", "c_e_s", "r_e_w", "i_r_e", "a_d_e", "p_l_e", "g_r_e", "l_i_k", "t_r_e", "q_u_i", "h_i_e", "l_a_n", "l_i_e", "v_e_d", "n_d_s", "c_h_e", "r_s_t", "o_r_d", "h_i_l", "c_a_n", "a_n_w", "m_a_y", "e_m_e", "e_n_e", "s_i_n", "i_e_f", "B_u_t", "e_r_i", "s_s_e", "l_l_e", "c_h_a", "p_t_a", "l_l_y", "o_n_d", "a_u_g", "e_t_h", "a_p_p", "r_r_i", "o_r_m", "d_a_y", "i_c_e", "B_r_a", "r_e_p", "d_i_d", "n_w_e", "f_t_e", "c_a_m", "s_e_n", "e_e_p", "p_e_a", "e_f_o", "r_e_e", "a_s_s", "t_i_l", "e_i_n", "o_p_e", "a_t_t", "i_s_h", "t_e_l", "d_a_r", "v_e_s", "p_p_e", "n_e_s", "t_o_r", "a_c_k", "o_n_t", "e_l_i", "b_r_o", "s_i_t", "o_k_e", "n_a_t", "f_a_c", "f_i_n", "a_m_p", "h_a_l", "o_m_p", "a_c_h", "f_o_u", "f_i_r", "h_o_s", "m_a_r", "m_e_s", "c_a_r", "e_y_e", "n_s_t", "l_a_t", "f_a_t", "h_e_s", "e_s_e", "w_o_m", "u_t_e", "l_a_i", "l_e_n", "i_n_s", "n_g_s", "w_i_n", "s_i_o", "a_r_n", "s_e_r", "l_l_o", "f_r_i", "e_x_p", "l_i_g", "i_t_y", "i_o_u", "d_e_e", "m_u_c", "m_u_s", "q_u_e", "e_e_m", "r_e_n", "i_t_s", "g_r_a", "t_r_u", "l_a_c", "n_d_i", "d_d_e", "i_n_k", "h_u_n", "t_a_k", "s_u_c", "a_i_r", "m_e_t", "s_a_y", "d_o_w", "e_a_l", "o_f_f", "u_t_h", "g_o_o", "v_i_n", "p_e_d", "r_a_c", "Y_o_u", "a_f_t", "t_i_c", "e_r_a", "n_e_r", "i_t_i", "h_a_r", "r_i_s", "h_e_l", "e_r_n", "n_t_s", "l_o_s", "r_i_o", "c_a_u", "a_s_e", "o_r_s", "h_o_r", "b_e_r", "o_n_l", "n_i_a", "o_n_c", "b_r_a", "m_s_e", "b_e_f", "m_e_a", "e_b_r", "o_s_s ...

# %% [markdown]
# # Part 2a: Smoothing and Backoff

# %%
import math 
def laplace_smoothing(n, n_grams):
    orig_ngram_count = get_and_sort(n, 100000, n_grams, 't')
    orig_lessngram_count = get_and_sort(1, 100000, n_grams, 't')
    
    total_ngram = sum([count for (_, count) in orig_ngram_count])
    total_lessngram = sum([count for (_, count) in orig_lessngram_count])
    
    enhanced_probs = list()
    
    for (gram, orig_freq) in orig_ngram_count:
        enhanced_probs.append((gram, (orig_freq + 1)/(total_ngram + 100000)))
    
    return enhanced_probs

def eq_classes(ngrams):
    eq_class = dict()
    for gram, freq in ngrams:
        if freq not in eq_class:
            eq_class[freq] = list()
        eq_class[freq].append(gram)
    return eq_class

def heldout(corpus, n):
    length = int(len(corpus)/2)
    #print(length)
    training = corpus[:length]
    heldout = corpus[-length:]
    utraining = get_and_sort(n, 1000, training, 't')
    uheldout = get_and_sort(n, 1000, heldout, 't')
    tr_eq_cls = eq_classes(utraining)
    hest = {}
    for r in tr_eq_cls:
        t_r = sum([uheldout[u][0] for u in tr_eq_cls[r] if u in utraining])
        hest[r] = t_r
        
    #N = sum(utraining[i][1] for i in )
    print (tr_eq_cls)
    return hest

def good_turing(n_grams):
    unigram_count = get_and_sort(1, 1000, n_grams, 't')
    # unigram_count is now a list of (gram, frequency)
    
    high_freq = unigram_count[0][1]
    
    # Good Turing first counts the number of ngrams of a particular freq 
    nrs = eq_classes(n_grams)
    nr_counts = {k : len(v) for k, v in nrs.items()}
    nr_probs = {k : (k*v)/float(N) for k, v in nr_counts.items()} # P = r * Nr / N
    sorted_nrs = sorted(nr_counts.items(), reverse = True)
    #sorted_probs = sorted(nr_probs.items())
    MAX = sorted_nrs[0][1]
    new_nrs = {}
    for r, nr in nrs.items():
        if (r+1) in nrs:
            new_nr = ((r+1) * nrs[r+1]) / float(N) 
        else:
            new_nr = MAX*r**-2 / float(N)
        new_nrs[r] = new_nr
    return new_nrs
          


# only 1 of the next 2 have to be implemented

def backoff(n_grams):
  # perform Backoff
    pass
  
def deleted_interpolation(n_grams):
  # perform deleted Interpolation
    pass

# %% [markdown]
# # Part 2 Executable

# %%
n = 2
lap_probs = laplace_smoothing(2, corpus)
print(lap_probs[:5])
print(lap_probs[-5:])

lap_probs = laplace_smoothing(n, characterized_corpus)
print(lap_probs[:5])
print(lap_probs[-5:])


eq_classes(bigrams_sorted)
# good_turing(bigrams_sorted)
# heldout(corpus, 2)
# Out:
# [(('of', 'the'), 0.003372745187206306), (('in', 'the'), 0.0017756989107603023), (('to', 'the'), 0.0017756989107603023), (('at', 'the'), 0.0011206392516078737), (('with', 'a'), 0.001082743238268477)]
# [(('is', 'founded'), 1.0827432382684771e-05), (('founded', 'this'), 1.0827432382684771e-05), (('this', 'Romance'), 1.0827432382684771e-05), (('Romance', 'of'), 1.0827432382684771e-05), (('THE', 'END'), 1.0827432382684771e-05)]
# [(('t', 'h'), 0.029463583737035892), (('h', 'e'), 0.028163605273605247), (('i', 'n'), 0.0171488176942378), (('a', 'n'), 0.014707141578293214), (('e', 'r'), 0.014670814834804135)]
# [(('O', 'w'), 5.189534784154274e-06), (('A', 'S'), 5.189534784154274e-06), (('f', 'n'), 5.189534784154274e-06), (('i', 'h'), 5.189534784154274e-06), (('x', 'o'), 5.189534784154274e-06)]
# {622: [('of', 'the')],
#  327: [('in', 'the'), ('to', 'the')],
#  206: [('at', 'the')],
#  199: [('with', 'a')],
#  169: [('the', 'prince')],
#  166: [('on', 'the')],
#  163: [('to', 'be')],
#  161: [('for', 'the')],
#  160: [('and', 'the')],
#  132: [('of', 'his')],
#  128: [('in', 'a')],
#  122: [('of', 'a')],
#  120: [('I', 'have')],
#  117: [('that', 'the')],
#  106: [('by', 'the')],
#  105: [('it', 'was')],
#  103: [('the', 'captain')],
#  102: [('I', 'am')],
#  97: [('had', 'been')],
#  95: [('did', 'not')],
#  94: [('from', 'the'), ('said', 'the')],
#  92: [('the', 'king')],
#  91: [('with', 'the')],
#  90: [('that', 'I')],
#  89: [('he', 'had')],
#  88: [('it', 'is'), ('the', 'Hebrew')],
#  87: [('was', 'a')],
#  86: [('to', 'his')],
#  84: [('returned', 'the'), ('that', 'he')],
#  82: [('into', 'the')],
#  79: [('have', 'been')],
#  77: [('he', 'was')],
#  76: [('as', 'he')],
#  74: [('a', 'few')],
#  72: [('I', 'will')],
#  69: [('one', 'of'), ('and', 'a'), ('and', 'I')],
#  66: [('the', 'chief'), ('for', 'a')],
#  65: [('the', 'same')],
#  64: [('is', 'a')],
#  63: [('old', 'woman')],
#  62: [('may', 'be'), ('the', 'old')],
#  61: [('he', 'said'), ('was', 'not')],
#  59: [('that', 'you')],
#  57: [('It', 'was')],
#  56: [('is', 'not')],
#  55: [('had', 'not')],
#  54: [('on', 'his'), ('in', 'his')],
#  53: [('It', 'is'), ('to', 'do'), ('as', 'if')],
#  52: [('out', 'of'), ('there', 'was')],
#  51: [('the', 'other'), ('the', 'princess')],
#  50: [('don', 't'), ('will', 'be'), ('if', 'you')],
#  49: [('as', 'well'), ('you', 'are'), ('I', 'know'), ('that', 'it')],
#  48: [('he', 'is'),
#   ('as', 'the'),
#   ('when', 'the'),
#   ('which', 'he'),
#   ('and', 'his')],
#  47: [('would', 'have')],
#  46: [('with', 'his')],
#  45: [('on', 'a'), ('they', 'were'), ('there', 'is'), ('was', 'the')],
#  44: [('but', 'I'), ('so', 'that'), ('I', 'can')],
#  43: [('of', 'them'),
#   ('we', 'have'),
#   ('you', 'have'),
#   ('a', 'little'),
#   ('a', 'good'),
#   ('to', 'a'),
#   ('and', 'that')],
#  42: [('as', 'a'), ('as', 'to'), ('to', 'me'), ('King', 'Hudibras')],
#  41: [('well', 'as'),
#   ('of', 'that'),
#   ('that', 'she'),
#   ('of', 'her'),
#   ('through', 'the')],
#  40: [('the', 'little'), ('to', 'see')],
#  39: [('could', 'not'), ('like', 'a'), ('be', 'a'), ('the', 'Hot')],
#  38: [('I', 'm'),
#   ('as', 'they'),
#   ('of', 'your'),
#   ('would', 'be'),
#   ('more', 'than')],
#  37: [('a', 'man'),
#   ('who', 'had'),
#   ('such', 'a'),
#   ('when', 'he'),
#   ('the', 'men'),
#   ('of', 'course'),
#   ('the', 'boy'),
#   ('Hot', 'Swamp')],
#  36: [('in', 'which'),
#   ('all', 'the'),
#   ('you', 'to'),
#   ('me', 'to'),
#   ('you', 'know'),
#   ('if', 'he'),
#   ('to', 'have'),
#   ('replied', 'the'),
#   ('the', 'woods'),
#   ('but', 'the')],
#  35: [('seemed', 'to'),
#   ('his', 'head'),
#   ('of', 'it'),
#   ('the', 'man'),
#   ('old', 'man'),
#   ('the', 'girl')],
#  34: [('which', 'the'),
#   ('over', 'the'),
#   ('the', 'time'),
#   ('few', 'minutes'),
#   ('and', 'in'),
#   ('she', 'had')],
#  33: [('I', 'would'),
#   ('for', 'he'),
#   ('you', 'will'),
#   ('for', 'I'),
#   ('to', 'her'),
#   ('and', 'he'),
#   ('to', 'make'),
#   ('the', 'hunter')],
#  32: [('in', 'her'),
#   ('I', 'shall'),
#   ('Captain', 'Arkal'),
#   ('to', 'him'),
#   ('we', 'are')],
#  31: [('at', 'that'),
#   ('not', 'to'),
#   ('and', 'it'),
#   ('by', 'a'),
#   ('are', 'not'),
#   ('at', 'once'),
#   ('as', 'you'),
#   ('the', 'lad')],
#  30: [('part', 'of'),
#   ('of', 'which'),
#   ('which', 'was'),
#   ('and', 'as'),
#   ('with', 'an'),
#   ('said', 'Bladud'),
#   ('know', 'that'),
#   ('up', 'and'),
#   ('began', 'to'),
#   ('for', 'it'),
#   ('was', 'to')],
#  29: [('do', 'you'),
#   ('has', 'been'),
#   ('to', 'say'),
#   ('I', 'think'),
#   ('as', 'it'),
#   ('into', 'a'),
#   ('exclaimed', 'the'),
#   ('not', 'been'),
#   ('He', 'was')],
#  28: [('Of', 'course'),
#   ('him', 'to'),
#   ('would', 'not'),
#   ('I', 'was'),
#   ('my', 'father'),
#   ('up', 'the'),
#   ('asked', 'the'),
#   ('not', 'a'),
#   ('the', 'Swamp')],
#  27: [('that', 'they'),
#   ('and', 'was'),
#   ('she', 'was'),
#   ('the', 'land'),
#   ('time', 'to'),
#   ('to', 'take'),
#   ('That', 'is'),
#   ('of', 'my'),
#   ('him', 'and'),
#   ('if', 'I'),
#   ('of', 'this'),
#   ('must', 'be'),
#   ('they', 'had'),
#   ('the', 'queen')],
#  26: [('not', 'yet'),
#   ('the', 'great'),
#   ('a', 'long'),
#   ('to', 'tell'),
#   ('come', 'to'),
#   ('in', 'this'),
#   ('look', 'of'),
#   ('he', 'has'),
#   ('that', 'we')],
#  25: [('from', 'his'),
#   ('at', 'least'),
#   ('answered', 'the'),
#   ('Bladud', 'and'),
#   ('about', 'the'),
#   ('it', 'would'),
#   ('to', 'find'),
#   ('a', 'look'),
#   ('that', 'time'),
#   ('way', 'to'),
#   ('a', 'time'),
#   ('seems', 'to')],
#  24: [('the', 'way'),
#   ('at', 'his'),
#   ('of', 'their'),
#   ('is', 'the'),
#   ('men', 'and'),
#   ('the', 'sea'),
#   ('There', 'was'),
#   ('for', 'you'),
#   ('at', 'all'),
#   ('was', 'so'),
#   ('side', 'of'),
#   ('that', 'is'),
#   ('with', 'her'),
#   ('of', 'Bladud'),
#   ('a', 'very')],
#  23: [('were', 'not'),
#   ('have', 'no'),
#   ('his', 'hand'),
#   ('I', 'had'),
#   ('in', 'all'),
#   ('must', 'have'),
#   ('when', 'I'),
#   ('at', 'last'),
#   ('to', 'my'),
#   ('state', 'of'),
#   ('for', 'his'),
#   ('in', 'that'),
#   ('but', 'it'),
#   ('the', 'first'),
#   ('to', 'go'),
#   ('the', 'ground'),
#   ('the', 'hut')],
#  22: [('eyes', 'and'),
#   ('I', 'don'),
#   ('tell', 'you'),
#   ('his', 'friend'),
#   ('not', 'so'),
#   ('father', 's'),
#   ('his', 'sword'),
#   ('who', 'was'),
#   ('that', 'had'),
#   ('I', 'should'),
#   ('was', 'no'),
#   ('Bladud', 's'),
#   ('the', 'whole'),
#   ('a', 'moment'),
#   ('sure', 'that')],
#  21: [('he', 'spoke'),
#   ('is', 'no'),
#   ('should', 'be'),
#   ('to', 'you'),
#   ('to', 'give'),
#   ('Bladud', 'was'),
#   ('I', 'must'),
#   ('have', 'a'),
#   ('I', 'do'),
#   ('any', 'one'),
#   ('no', 'doubt'),
#   ('that', 'of'),
#   ('as', 'I'),
#   ('the', 'water'),
#   ('little', 'Maikar'),
#   ('of', 'our'),
#   ('and', 'then'),
#   ('and', 'to'),
#   ('while', 'the'),
#   ('the', 'camp'),
#   ('is', 'to')],
#  20: [('they', 'are'),
#   ('have', 'not'),
#   ('the', 'two'),
#   ('we', 'may'),
#   ('with', 'me'),
#   ('be', 'the'),
#   ('you', 'and'),
#   ('man', 'of'),
#   ('might', 'be'),
#   ('which', 'had'),
#   ('he', 'would'),
#   ('end', 'of'),
#   ('There', 'is'),
#   ('as', 'she'),
#   ('among', 'the'),
#   ('what', 'I'),
#   ('that', 'was')],
#  19: [('At', 'the'),
#   ('does', 'not'),
#   ('in', 'those'),
#   ('sort', 'of'),
#   ('about', 'to'),
#   ('you', 'would'),
#   ('some', 'of'),
#   ('enough', 'to'),
#   ('under', 'the'),
#   ('he', 'could'),
#   ('to', 'keep'),
#   ('is', 'well'),
#   ('of', 'him'),
#   ('found', 'that'),
#   ('the', 'end'),
#   ('of', 'what'),
#   ('the', 'river'),
#   ('the', 'forest'),
#   ('to', 'come'),
#   ('each', 'other'),
#   ('But', 'I'),
#   ('as', 'we'),
#   ('an', 'old'),
#   ('the', 'palace'),
#   ('search', 'for')],
#  18: [('to', 'that'),
#   ('the', 'young'),
#   ('if', 'it'),
#   ('of', 'all'),
#   ('if', 'we'),
#   ('up', 'to'),
#   ('him', 'with'),
#   ('him', 'in'),
#   ('young', 'man'),
#   ('in', 'my'),
#   ('a', 'laugh'),
#   ('instead', 'of'),
#   ('down', 'the'),
#   ('the', 'fact'),
#   ('before', 'the'),
#   ('man', 'and'),
#   ('to', 'look'),
#   ('me', 'that'),
#   ('could', 'be'),
#   ('I', 'see'),
#   ('time', 'and'),
#   ('that', 'there'),
#   ('tell', 'me'),
#   ('his', 'eyes'),
#   ('and', 'looked'),
#   ('not', 'only'),
#   ('it', 'and'),
#   ('the', 'place'),
#   ('one', 'who'),
#   ('returned', 'to'),
#   ('he', 'did'),
#   ('that', 'if'),
#   ('what', 'you'),
#   ('of', 'King'),
#   ('I', 'want')],
#  17: [('his', 'hut'),
#   ('remarked', 'the'),
#   ('head', 'and'),
#   ('will', 'not'),
#   ('man', 'who'),
#   ('I', 'may'),
#   ('with', 'him'),
#   ('and', 'they'),
#   ('you', 'may'),
#   ('say', 'that'),
#   ('your', 'father'),
#   ('those', 'days'),
#   ('men', 'of'),
#   ('with', 'which'),
#   ('for', 'they'),
#   ('I', 'did'),
#   ('with', 'some'),
#   ('I', 'could'),
#   ('seem', 'to'),
#   ('at', 'this'),
#   ('where', 'the'),
#   ('and', 'let'),
#   ('to', 'let'),
#   ('the', 'head'),
#   ('those', 'of'),
#   ('up', 'his'),
#   ('it', 'for'),
#   ('continued', 'the'),
#   ('at', 'first'),
#   ('an', 'arrow'),
#   ('cried', 'the'),
#   ('all', 'events'),
#   ('that', 'a'),
#   ('fond', 'of'),
#   ('and', 'you'),
#   ('thought', 'of'),
#   ('the', 'doctor'),
#   ('the', 'scout')],
#  16: [('but', 'he'),
#   ('a', 'large'),
#   ('of', 'these'),
#   ('the', 'youth'),
#   ('do', 'so'),
#   ('I', 'hope'),
#   ('the', 'last'),
#   ('if', 'the'),
#   ('do', 'not'),
#   ('I', 'cannot'),
#   ('or', 'two'),
#   ('the', 'day'),
#   ('it', 'had'),
#   ('the', 'poor'),
#   ('you', 'see'),
#   ('which', 'is'),
#   ('it', 'in'),
#   ('not', 'quite'),
#   ('he', 'found'),
#   ('up', 'with'),
#   ('and', 'with'),
#   ('men', 'who'),
#   ('fact', 'that'),
#   ('not', 'be'),
#   ('after', 'the'),
#   ('may', 'not'),
#   ('other', 'side'),
#   ('for', 'some'),
#   ('some', 'time'),
#   ('the', 'fire'),
#   ('be', 'done'),
#   ('his', 'bow'),
#   ('left', 'the'),
#   ('the', 'face'),
#   ('I', 'll'),
#   ('she', 'is'),
#   ('and', 'she'),
#   ('to', 'speak'),
#   ('her', 'and'),
#   ('not', 'the'),
#   ('little', 'old'),
#   ('of', 'Gadarn')],
#  15: [('search', 'of'),
#   ('the', 'door'),
#   ('and', 'had'),
#   ('round', 'the'),
#   ('air', 'of'),
#   ('the', 'latter'),
#   ('to', 'know'),
#   ('to', 'get'),
#   ('with', 'you'),
#   ('I', 'feel'),
#   ('She', 'was'),
#   ('the', '_Penelope_'),
#   ('of', 'one'),
#   ('a', 'small'),
#   ('when', 'you'),
#   ('to', 'think'),
#   ('Do', 'you'),
#   ('for', 'my'),
#   ('such', 'an'),
#   ('what', 'is'),
#   ('that', 'his'),
#   ('about', 'it'),
#   ('but', 'we'),
#   ('this', 'point'),
#   ('for', 'that'),
#   ('there', 'are'),
#   ('think', 'of'),
#   ('It', 'may'),
#   ('bow', 'and'),
#   ('reached', 'the'),
#   ('had', 'to'),
#   ('You', 'are'),
#   ('that', 'day'),
#   ('well', 'known'),
#   ('This', 'was'),
#   ('Then', 'he'),
#   ('am', 'not'),
#   ('the', 'woman'),
#   ('her', 'to'),
#   ('let', 'me'),
#   ('his', 'daughter'),
#   ('his', 'own'),
#   ('the', 'pup')],
#  14: [('the', 'town'),
#   ('turning', 'to'),
#   ('were', 'in'),
#   ('the', 'East'),
#   ('a', 'wild'),
#   ('of', 'you'),
#   ('is', 'that'),
#   ('was', 'an'),
#   ('the', 'very'),
#   ('nature', 'of'),
#   ('you', 'think'),
#   ('the', 'bow'),
#   ('caused', 'the'),
#   ('not', 'have'),
#   ('and', 'no'),
#   ('and', 'when'),
#   ('to', 'morrow'),
#   ('towards', 'the'),
#   ('But', 'the'),
#   ('and', 'there'),
#   ('you', 'not'),
#   ('time', 'the'),
#   ('than', 'a'),
#   ('how', 'to'),
#   ('have', 'to'),
#   ('we', 'shall'),
#   ('the', 'spot'),
#   ('when', 'they'),
#   ('it', 'were'),
#   ('them', 'to'),
#   ('the', 'direction'),
#   ('far', 'from'),
#   ('too', 'much'),
#   ('his', 'father'),
#   ('quite', 'sure'),
#   ('at', 'a'),
#   ('of', 'Gunrig'),
#   ('her', 'face'),
#   ('Gunrig', 's'),
#   ('for', 'him'),
#   ('him', 'a'),
#   ('The', 'Hebrew'),
#   ('the', 'search'),
#   ('the', 'disease'),
#   ('the', 'pigs'),
#   ('Gadarn', 's')],
#  13: [('of', 'those'),
#   ('in', 'search'),
#   ('had', 'no'),
#   ('referred', 'to'),
#   ('though', 'he'),
#   ('captain', 'with'),
#   ('I', 'fear'),
#   ('point', 'of'),
#   ('I', 'suppose'),
#   ('the', 'air'),
#   ('desire', 'to'),
#   ('the', 'world'),
#   ('though', 'I'),
#   ('the', 'games'),
#   ('tone', 'of'),
#   ('it', 'will'),
#   ('away', 'from'),
#   ('of', 'mind'),
#   ('which', 'they'),
#   ('during', 'the'),
#   ('on', 'their'),
#   ('and', 'made'),
#   ('it', 'to'),
#   ('to', 'Bladud'),
#   ('we', 'must'),
#   ('to', 'it'),
#   ('that', 'Bladud'),
#   ('by', 'that'),
#   ('I', 'never'),
#   ('with', 'such'),
#   ('had', 'a'),
#   ('Don', 't'),
#   ('t', 'you'),
#   ('of', 'us'),
#   ('when', 'we'),
#   ('that', 'moment'),
#   ('down', 'on'),
#   ('shall', 'have'),
#   ('go', 'to'),
#   ('many', 'of'),
#   ('back', 'and'),
#   ('the', 'night'),
#   ('sure', 'to'),
#   ('At', 'all'),
#   ('but', 'that'),
#   ('came', 'to'),
#   ('should', 'have'),
#   ('go', 'and'),
#   ('He', 'is'),
#   ('her', 'friend'),
#   ('which', 'were'),
#   ('you', 'for'),
#   ('my', 'dear'),
#   ('the', 'cause'),
#   ('her', 'eyes'),
#   ('Hebrew', 's'),
#   ('when', 'she'),
#   ('the', 'All'),
#   ('All', 'seeing'),
#   ('hunter', 'of'),
#   ('the', 'swamp')],
#  12: [('beyond', 'the'),
#   ('young', 'men'),
#   ('as', 'his'),
#   ('make', 'a'),
#   ('the', 'wind'),
#   ('the', 'point'),
#   ('Prince', 'Bladud'),
#   ('The', 'prince'),
#   ('a', 'sort'),
#   ('to', 'this'),
#   ('and', 'at'),
#   ('shall', 'be'),
#   ('a', 'slight'),
#   ('to', 'run'),
#   ('me', 'and'),
#   ('the', 'most'),
#   ('father', 'and'),
#   ('so', 'I'),
#   ('for', 'your'),
#   ('on', 'her'),
#   ('in', 'such'),
#   ('that', 'will'),
#   ('you', 'can'),
#   ('you', 'had'),
#   ('with', 'your'),
#   ('with', 'that'),
#   ('to', 'their'),
#   ('on', 'one'),
#   ('from', 'which'),
#   ('I', 'saw'),
#   ('of', 'men'),
#   ('my', 'head'),
#   ('I', 've'),
#   ('to', 'your'),
#   ('he', 'will'),
#   ('the', 'beginning'),
#   ('out', 'the'),
#   ('Bladud', 'had'),
#   ('only', 'a'),
#   ('little', 'man'),
#   ('on', 'this'),
#   ('man', 'with'),
#   ('a', 'short'),
#   ('in', 'your'),
#   ('is', 'true'),
#   ('is', 'it'),
#   ('regard', 'to'),
#   ('In', 'a'),
#   ('out', 'to'),
#   ('so', 'as'),
#   ('off', 'the'),
#   ('have', 'the'),
#   ('was', 'in'),
#   ('let', 'us'),
#   ('expression', 'of'),
#   ('had', 'left'),
#   ('a', 'tone'),
#   ('may', 'have'),
#   ('up', 'in'),
#   ('we', 'will'),
#   ('have', 'said'),
#   ('the', 'party'),
#   ('A', 'few'),
#   ('on', 'your'),
#   ('of', 'being'),
#   ('be', 'no'),
#   ('of', 'any'),
#   ('be', 'sure'),
#   ('with', 'all'),
#   ('him', 'for'),
#   ('go', 'on'),
#   ('what', 'he'),
#   ('they', 'will'),
#   ('know', 'not'),
#   ('on', 'my'),
#   ('found', 'the'),
#   ('down', 'to'),
#   ('have', 'seen'),
#   ('a', 'great'),
#   ('have', 'you'),
#   ('to', 'wed'),
#   ('king', 'and'),
#   ('Hafrydda', 'and'),
#   ('he', 'knew'),
#   ('seeing', 'One'),
#   ('for', 'her'),
#   ('she', 'could')],
#  11: [('and', 'even'),
#   ('the', 'only'),
#   ('ready', 'to'),
#   ('a', 'sudden'),
#   ('looked', 'up'),
#   ('of', 'some'),
#   ('than', 'I'),
#   ('it', 'may'),
#   ('returned', 'Bladud'),
#   ('You', 'know'),
#   ('for', 'me'),
#   ('asked', 'Bladud'),
#   ('in', 'surprise'),
#   ('purpose', 'of'),
#   ('upon', 'the'),
#   ('by', 'his'),
#   ('in', 'advance'),
#   ('a', 'low'),
#   ('man', 's'),
#   ('good', 'deal'),
#   ('mean', 'to'),
#   ('by', 'this'),
#   ('Bladud', 'with'),
#   ('between', 'the'),
#   ('man', 'in'),
#   ('the', 'moment'),
#   ('his', 'back'),
#   ('them', 'as'),
#   ('where', 'he'),
#   ('himself', 'and'),
#   ('him', 'as'),
#   ('and', 'my'),
#   ('home', 'and'),
#   ('like', 'to'),
#   ('but', 'a'),
#   ('heard', 'of'),
#   ('something', 'like'),
#   ('it', 'seems'),
#   ('my', 'own'),
#   ('of', 'Albion'),
#   ('the', 'people'),
#   ('so', 'much'),
#   ('followed', 'by'),
#   ('going', 'to'),
#   ('until', 'the'),
#   ('the', 'right'),
#   ('was', 'still'),
#   ('to', 'die'),
#   ('men', 'to'),
#   ('against', 'the'),
#   ('looked', 'at'),
#   ('now', 'and'),
#   ('am', 'I'),
#   ('course', 'the'),
#   ('entered', 'the'),
#   ('and', 'so'),
#   ('be', 'seen'),
#   ('and', 'see'),
#   ('the', 'plank'),
#   ('the', 'bear'),
#   ('head', 'of'),
#   ('into', 'my'),
#   ('had', 'come'),
#   ('said', 'that'),
#   ('and', 'if'),
#   ('able', 'to'),
#   ('t', 'be'),
#   ('in', 'front'),
#   ('you', 'say'),
#   ('in', 'some'),
#   ('all', 'directions'),
#   ('not', 'far'),
#   ('of', 'an'),
#   ('burst', 'into'),
#   ('resolved', 'to'),
#   ('is', 'so'),
#   ('way', 'of'),
#   ('it', 'has'),
#   ('his', 'life'),
#   ('a', 'strange'),
#   ('my', 'mind'),
#   ('be', 'so'),
#   ('you', 'were'),
#   ('told', 'me'),
#   ('his', 'way'),
#   ('woman', 'in'),
#   ('king', 's'),
#   ('but', 'she'),
#   ('what', 'was'),
#   ('northern', 'chief'),
#   ('but', 'when'),
#   ('chief', 'was'),
#   ('in', 'time'),
#   ('same', 'time'),
#   ('you', 'do'),
#   ('cause', 'of'),
#   ('near', 'the'),
#   ('know', 'what'),
#   ('my', 'son'),
#   ('the', 'room'),
#   ('find', 'the'),
#   ('his', 'men'),
#   ('Swamp', 'and')],
#  10: [('in', 'one'),
#   ('given', 'to'),
#   ('the', 'mate'),
#   ('the', 'vessel'),
#   ('a', 'band'),
#   ('band', 'of'),
#   ('but', 'you'),
#   ('no', 'one'),
#   ('he', 'added'),
#   ('could', 'have'),
#   ('engaged', 'in'),
#   ('most', 'of'),
#   ('return', 'to'),
#   ('who', 'has'),
#   ('give', 'you'),
#   ('been', 'a'),
#   ('be', 'to'),
#   ('say', 'truth'),
#   ('though', 'not'),
#   ('where', 'I'),
#   ('Bladud', 'in'),
#   ('won', 't'),
#   ('face', 'and'),
#   ('the', 'sail'),
#   ('on', 'which'),
#   ('full', 'of'),
#   ('or', 'the'),
#   ('and', 'not'),
#   ('the', 'result'),
#   ('I', 'thought'),
#   ('used', 'to'),
#   ('As', 'he'),
#   ('power', 'of'),
#   ('just', 'now'),
#   ('in', 'silence'),
#   ('one', 'side'),
#   ('they', 'did'),
#   ('a', 'state'),
#   ('over', 'his'),
#   ('say', 'you'),
#   ('when', 'it'),
#   ('Arkal', 'and'),
#   ('think', 'that'),
#   ('the', 'conversation'),
#   ('to', 'day'),
#   ('so', 'far'),
#   ('the', 'question'),
#   ('is', 'more'),
#   ('said', 'to'),
#   ('much', 'to'),
#   ('which', 'I'),
#   ('It', 'would'),
#   ('if', 'they'),
#   ('but', 'as'),
#   ('to', 'act'),
#   ('corner', 'of'),
#   ('at', 'such'),
#   ('for', 'there'),
#   ('it', 'so'),
#   ('moment', 'and'),
#   ('her', 'for'),
#   ('had', 'just'),
#   ('of', 'great'),
#   ('after', 'a'),
#   ('to', 'some'),
#   ('the', 'wild'),
#   ('not', 'know'),
#   ('know', 'it'),
#   ('face', 'of'),
#   ('and', 'almost'),
#   ('but', 'there'),
#   ('you', 'must'),
#   ('made', 'up'),
#   ('Have', 'you'),
#   ('the', 'country'),
#   ('it', 'not'),
#   ('the', 'hot'),
#   ('see', 'that'),
#   ('him', 'at'),
#   ('and', 'tell'),
#   ('all', 'his'),
#   ('the', 'dark'),
#   ('prince', 'with'),
#   ('much', 'for'),
#   ('that', 'my'),
#   ('to', 'understand'),
#   ('news', 'of'),
#   ('went', 'to'),
#   ('was', 'as'),
#   ('Branwen', 's'),
#   ('his', 'mind'),
#   ('of', 'life'),
#   ('the', 'best'),
#   ('has', 'not'),
#   ('which', 'she'),
#   ('her', 'hand'),
#   ('at', 'her'),
#   ('run', 'away'),
#   ('of', 'Branwen'),
#   ('she', 'replied'),
#   ('the', 'neighbourhood'),
#   ('was', 'at'),
#   ('be', 'found'),
#   ('CHAPTER', 'TWENTY'),
#   ('sure', 'of'),
#   ('the', 'officer'),
#   ('lad', 'Cormac'),
#   ('hot', 'water')],
#  9: [('of', 'such'),
#   ('his', 'feet'),
#   ('a', 'loud'),
#   ('to', 'set'),
#   ('up', 'a'),
#   ('but', 'they'),
#   ('prince', 'and'),
#   ('men', 'in'),
#   ('prince', 'was'),
#   ('black', 'eyes'),
#   ('more', 'of'),
#   ('be', 'that'),
#   ('as', 'far'),
#   ('far', 'as'),
#   ('me', 'a'),
#   ('have', 'had'),
#   ('to', 'visit'),
#   ('but', 'his'),
#   ('will', 'never'),
#   ('Indeed', 'I'),
#   ('your', 'head'),
#   ('to', 'which'),
#   ('the', 'gale'),
#   ('chance', 'of'),
#   ('For', 'a'),
#   ('No', 'I'),
#   ('you', 'shall'),
#   ('took', 'up'),
#   ('it', 'on'),
#   ('with', 'it'),
#   ('a', 'neighbouring'),
#   ('and', 'have'),
#   ('a', 'pretty'),
#   ('can', 'be'),
#   ('had', 'seen'),
#   ('your', 'own'),
#   ('They', 'were'),
#   ('the', 'enemy'),
#   ('did', 'so'),
#   ('have', 'done'),
#   ('it', 'with'),
#   ('now', 'that'),
#   ('will', 'do'),
#   ('many', 'a'),
#   ('It', 'seems'),
#   ('saw', 'the'),
#   ('he', 's'),
#   ('in', 'an'),
#   ('something', 'of'),
#   ('Bladud', 'to'),
#   ('course', 'I'),
#   ('Maikar', 'and'),
#   ('the', 'morning'),
#   ('close', 'to'),
#   ('the', 'bank'),
#   ('day', 'and'),
#   ('this', 'was'),
#   ('equal', 'to'),
#   ('he', 'felt'),
#   ('inclined', 'to'),
#   ('sight', 'of'),
#   ('was', 'right'),
#   ('of', 'me'),
#   ('Are', 'you'),
#   ('the', 'three'),
#   ('see', 'the'),
#   ('a', 'place'),
#   ('that', 'in'),
#   ('and', 'Maikar'),
#   ('was', 'about'),
#   ('out', 'and'),
#   ('his', 'mouth'),
#   ('back', 'to'),
#   ('in', 'it'),
#   ('to', 'return'),
#   ('from', 'this'),
#   ('idea', 'of'),
#   ('is', 'my'),
#   ('it', 'be'),
#   ('to', 'work'),
#   ('you', 'could'),
#   ('it', 'as'),
#   ('the', 'case'),
#   ('a', 'tree'),
#   ('and', 'stood'),
#   ('that', 'no'),
#   ('the', 'sun'),
#   ('for', 'if'),
#   ('his', 'hands'),
#   ('it', 'out'),
#   ('his', 'friends'),
#   ('but', 'what'),
#   ('let', 'the'),
#   ('are', 'right'),
#   ('since', 'I'),
#   ('his', 'arm'),
#   ('the', 'boar'),
#   ('that', 'would'),
#   ('a', 'strong'),
#   ('been', 'the')]}

# %% [markdown]
# # Part 3: Grammatical Score

# %%
def conditional_probs (corpus, ngram):
    #Pr(w1|w2) = Pr(w1, w2)/Pr(w2)
    n = len(ngram)
    n_less_gram = list()
    i = 0
    for i in range(n-1):
        n_less_gram.append(ngram[i])
    if n > 2:
        n_less = tuple(n_less_gram)
    else:
        n_less = n_less_gram[0]
    n_lap_probs = laplace_smoothing(n, corpus)
    nless_lap_probs = laplace_smoothing(n-1, corpus)
    
    cond_prob = 0.000000001
    numerator = 0.000000001
    for (n_gram, val) in n_lap_probs:
        if ngram == n_gram:
            numerator = val
            break

    denominator = 100000000
    for n_gram, value in nless_lap_probs:
        if n_less == n_gram:
            denominator = value
            break    
    
    return numerator/denominator

def grammar_score(sentence, n):
    # create n-grams from sentence
    size = len(sentence[0])
    n_grams = get_ngrams(n, sentence)
    score = 0
    for ngram in n_grams:
        if score != 0:
            score *= float(conditional_probs(corpus, ngram))
        else:
            score = float(conditional_probs(corpus, ngram))
    # normalize_score based on length
    # total number of sentences of that length = V^size for size > 3 and V^size/2 for size <= 3
    # so the score should represent how likely it is, by dividing the score by some function of the size 
    # which is an accurate representation of the probability of that sentence
    return score

test = "This is a lovely man."
 
cleaned_test = clean(test)
split_test = sentencizer(cleaned_test)
untokenized_test = []
for sentence in split_test:
    untokenized_test.append([sentence])    
test_corpus = tokenize (untokenized_test)

grammar_score (test_corpus, 3)
#print(len(test_corpus[0]))
# Out:
# 3.591173812634585e-15

# %% [markdown]
# # Part 4 : Spelling Test

# %%
def spelling_score(word, n):
    # create n-grams from sentence
    #size = len(word[0])
    n_grams = get_ngrams(n, [word])
    score = 0
    for ngram in n_grams:
        if score != 0:
            score *= float(conditional_probs(characterized_corpus, ngram))
        else:
            score = float(conditional_probs(characterized_corpus, ngram))
    # normalize_score based on length
    # total number of sentences of that length = V^size for size > 3 and V^size/2 for size <= 3
    # so the score should represent how likely it is, by dividing the score by some function of the size 
    # which is an accurate representation of the probability of that sentence
    return score

test = "This"
 
cleaned_test = clean(test)
characterized_test_corpus = characterizer(cleaned_test)

spelling_score(characterized_test_corpus, 3)
# Out:
# 0.05558790844239914
